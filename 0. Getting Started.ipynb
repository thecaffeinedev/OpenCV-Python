# %% [markdown]
# #### See where your python.exe is located

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %% [markdown]
# #### See your working directory

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Prabhat\Desktop\Computer Vision\1.OpenCV

# %% [markdown]
# #### Test your imports

# %%
import cv2
import numpy as np
import matplotlib

# %% [markdown]
# #### Display the version of OpenCV

# %%
print(cv2.__version__)
# Out:
# 3.3.0
